# %% [markdown]
# # **Matplotlib :**
#
# - Allows us to Plot and Visualize our Data at Hand.
# - Turn our data into some pretty visualizations (Plots & figures).
#
# Where we use `Matplotlib` in Data science Project.
#
# (in **Data Analysis** part)
#
# <img src="../4.%20Pandas%20:%20Data%20Analysis/images/tools2.png" width=60%>
#
# ## **Why Matplotlib !??**
#
# 1. Easy to use, built on top of NumPy arrays & Python that provides ease.
# 2. Integrates directly with Pandas.
# 3. Allows to Create Visualizations - basic to advanced.
# 4. Easy to customize, simple Interface.
#
# #### **Matplotlib Anatomy :**
#
# <img src="Images/matplotlib-anatomy-of-a-plot.png" width=60%>
#
# - **Also [Matplotlib Anatomy with Code](Images/matplotlib-anatomy-of-a-plot-with-code.png)**.
#
# **`Let's Plot !!`**
#
# ![](https://media.giphy.com/media/3og0IExSrnfW2kUaaI/giphy.gif)

# %% [markdown]
# ### **`Additional :`**
#
# **_I Found few deep & detailed articles about `Matplotlib approaches`, extremely brain-storming._**
#
# **If you have some pre-knowledge of Matplotlib, Just read that Awesome articles :**
#
# - [Pybloggers](http://www.pybloggers.com/2018/02/python-plotting-with-matplotlib-guide/): Python plotting with matplotlib guide.
# - [OpenDataScience](https://opendatascience.com/getting-started-with-data-visualization-library-in-python-matplotlib/): Getting Started with Matplotlib

# %%
# Allow Matplotlib figures to be displayed on Jupyter Notebook.
# %matplotlib inline # jupyter's magic command

# import required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## **`matplotlib.pyplot` | Stateful approach | 1st Way:**
#
# - pyplot API plots in a stateful plotting.
# - It is generally less-flexible .
# - It works ever with current figure & current axes only.
# - Directly pyplot functions are used for this **like** `plt.plot`, `plt.ylabel` etc.

# %%
# Simplest plot | Line Plot using plt.plot() | plot x Vs y as lines/markers
plt.plot() # No-data | empty figure
plt.show() # show our plot

# %%
# Let's plot a 1D Data
plt.plot([2, 4, 6, 8, 10],) # single-axis value 
plt.show()

# %%
# Let's create X Vs y plot.
x = [2, 4, 6, 8, 10]
y = [1, 3, 5, 7, 9] # Called State-less plotting 

plt.plot(x, y) # Two-axes
plt.show()

# %%
# Another Example of Stateful approach of plotting.
plt.scatter(x, y)
plt.xlabel("X_Axis") # Set x-label of current Axes
plt.ylabel("Y_Axis") # Set y-label.
# Setting x-axis & y-axis limits
plt.ylim(0, 12)
plt.xlim(0, 12)
plt.show() # show current Figure. # all figures are lost here!

# %%
# (It's Complex) I have worked with it so let's do!!

# Stateful approach | Single Figure with Multiple Axes.
# Create the first subplot
plt.subplot(2, 2, 1)
plt.scatter([1, 2, 3], [4, 5, 6])
plt.title("Subplot 1")

# Create the second subplot
plt.subplot(2, 2, 2)
plt.plot([1, 2, 3], [2, 4, 6])
plt.title("Subplot 2")

# Create the third subplot
plt.subplot(2, 2, 3)
plt.bar([1, 2, 3], [5, 3, 7])
plt.title("Subplot 3")

# Create the fourth subplot
plt.subplot(2, 2, 4)
plt.plot([1, 2, 3], [8, 1, 4])
plt.title("Subplot 4")

# Title to Figure 
plt.suptitle("'Stateful Plot'\nFigure with Multiple Axes", fontdict={"size":15, "weight":"bold", "color": "Orange"})

# Adjust spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

# %% [markdown]
# **Let's Look more flexible appraoch!**
#
# ## **`matplotlib` | Object-Oriented Approach | 2nd Way:**
#
# - In the object-oriented approach, you create explicit figure and axes objects.
# - This method provides more control over layout and customization.
# - Each axes object corresponds to a subplot and can be customized individually.
# - Customization of elements like labels and titles is done using dedicated methods.
# - Preferred for complex layouts and multi-panel visualizations.
#
# **Let's see multiple ways to do `Object Oriented Plotting` with Matplotlib.**

# %%
# 1st Method
fig = plt.figure() # Create new Figure obj
ax = fig.add_subplot() # Add axes obj in it.
plt.show() # show

# %%
# 2nd Method
fig = plt.figure() # Create new figure obj
ax = fig.add_axes(rect=(.7, .7, .7, .7)) # Create new axes obj  ## with given size
ax.plot(x, y)
plt.show()

# %%
# 3rd Method (Recommended by instructor)
fig, ax = plt.subplots() # Axes with Figure objects
ax.plot(x, y); # Plotting (";" for showing appropriately)

# %% [markdown]
# ### Let's Understand [Matplotlib Anatomy](#matplotlib-anatomy) Again !!
#
# Some Official resources - [Here](https://matplotlib.org/stable/gallery/showcase/anatomy.html#anatomy-of-a-figure). (`Insightful`)
#
# ## **Matplotlib Workflow :**
#
# - This general steps are used to Visualize data in a Project!!

# %%
# 1. Importing matplotlib & getting ready to visualize in Jupyter.
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# 2. Preparing Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# 3. Creating figure & axes.
fig, axes = plt.subplots(figsize=(10, 7))

# 4. Plotting data.
axes.scatter(x, y,
            color='w', edgecolor='b'
        )
# 5. Customizing the Plot
axes.set(
    xlabel='x',
    ylabel='sin(x)',
    title='Title - sin(x) vs. x',
)
axes.title.set_fontsize(20) # Size of Title.

# 6. save the Figure
fig.savefig("Images/scatter.png")

# %% [markdown]
# #### **Making Visualizations using NumPy Arrays.**
#
# Here We'll plot the most common graphs :
#
# - Line plot
# - Scatter plot
# - Bar plot
# - Histogram
# - Subplots etc.

# %%
import numpy as np

# Generate Data for plotting
x = np.linspace(1, 10, 100) # Linear spaced 100 nums
x[:5]
# Out:
# array([1.        , 1.09090909, 1.18181818, 1.27272727, 1.36363636])

# %%
# Plotting Line Plot
fig, ax = plt.subplots()
ax.plot(x, x**3, 'g--')
plt.show()

# %%
## Plotting Scatter Plot
fig, ax = plt.subplots()
ax.scatter(x, np.cos(y)) # Scatter plot on data.
plt.show()

# %%
# Another Scatter Plot
fig, ax = plt.subplots()
ax.scatter(y, np.cos(y)) # Plotting random Data for Now!!
plt.show()

# %%
# Plotting Bar plot.

# Data in Dictionary
bar_data = dict(
    HP_Victus=9.5,
    Asus_Vivobook=9,
    Acer_Gaming=6,
    Dell_XPS = 9.7,
    My_Old_Lap = 10,
    Asus_ROG = 8    
)

# Plotting Bar plot
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(
    bar_data.keys(), 
    bar_data.values()
)
ax.set(
    xlabel="Laptops",
    ylabel="Rating",
)
ax.set_title("Rating of Laptops", fontsize=22, color='gold')
plt.show()
# We can also plot horizontal Bar Plots via `barh` function.

# %%
# Creating a Histogram. (Shows Distribution of Data).

# Dummy data (Normally Distributed).
x = np.random.randn(1000)

# Plot this Data.
fig, ax = plt.subplots(figsize=(8, 5))
ax.hist(x, density=True)
ax.set(
    xlabel='Values',
    ylabel='Frequency'
)
ax.set_title("Histogram | Normally Distributed\n", size=16, color="skyblue")
plt.show()

# %% [markdown]
# ### **Two Different Options for Subplot :**
#     Multiple Axes objects within the same figure.
#
# 1. Directly Unpacking into different axes objects.
# 2. Storing as an Array in a Variable, then using via grid i.e. `ax[0, 0], ax[0, 1]` etc.

# %%
# Option 1

# Single Figure wit 2 Axes (graphs) | 1 row & 2 column.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plotting random dummy data.

# First Plot | Line plot
ax1.plot(x.cumsum(), "g-", linewidth=4.5)
ax1.set(
    title="Line Plot",
    xlabel="x-axis",
    ylabel="y-axis",
)

# Second Plot | Histogram plot
ax2.hist(np.random.randn(1000))
ax2.set(
    title="Histogram Plot",
    xlabel="x-axis",
    ylabel="y-axis",
)

# Display Figure
fig.suptitle("Subplots Figure  | Multiple Axes", size=16, fontdict={'weight':'bolder', 'color':'greenyellow'})
fig.tight_layout()
plt.show()

# %%
# Option 2

# Single Figure wit 2 Axes (graphs) | 1 row & 2 column.
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Plotting random dummy data.

# First Plot | Line plot
ax[0].plot(x.cumsum(), "g-", linewidth=4.5)
ax[0].set(
    title="Line Plot",
    xlabel="x-axis",
    ylabel="y-axis",
)

# Second Plot | Histogram plot
ax[1].hist(np.random.randn(1000))
ax[1].set(
    title="Histogram Plot",
    xlabel="x-axis",
    ylabel="y-axis",
)

# Display Figure
fig.suptitle("Subplots Figure  | Multiple Axes", size=16, fontdict={'weight':'bolder', 'color':'greenyellow'})
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Plotting with Pandas DataFrame :
#
# As we won't use `NumPy Arrays ` to Create Visualizations that often.
#
# **Let's Plot the Data Using Pandas `DataFrames`**.

# %%
# Let's import
import pandas as pd

# %%
# Importing `Car_sales.csv` in Pandas `DataFrame`.
car_sales = pd.read_csv("CSVs/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# #### Always try to look some Documentation.
# Here's Official Documentationm for Pandas [Plotting](https://pandas.pydata.org/docs/user_guide/visualization.html).
#
# Pandas uses Matplotlib at the backend, to create these visualizations, so we can use all the matplotlib objects, methods etc. to customize our graphs.

# %%
## Creating a Random Series to visualize it's cumulative sum. (numpy.random | seed=27)
np.random.seed(27)

random_series = pd.Series(
    np.random.randn(100),
    index= pd.date_range("6 september 2023", "6 september 2024", periods=100) # DateTime index.
    )

cumsum = random_series.cumsum() # cumulative sum
ax = cumsum.plot(color='yellow', marker='.'); # Plot a Line Graph.

date_format = plt.matplotlib.dates.DateFormatter('%d %b %Y') # matplotlib date formatter.
ax.xaxis.set_major_formatter(date_format)

plt.show()

# %% [markdown]
# #### **Plotting From Pandas DataFrame :**
#
# Using Car_sales CSV File.

# %%
## Let's View Car_sales DataFrame Again !!
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
## Again, Like we have seen before!
## Check the Information of the DataFrame.
## Check Data Types of each columns. (They are appropriate or not?)
car_sales.info() # Price col must be in Integer DataType.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
# Convert data type of `Price` column using RegEx.
car_sales.Price = car_sales.Price.str.replace(
                "[\D]",
                "",
                regex=True
        ).str.removesuffix("00").astype(int)

car_sales.Price ## Converted correctly to int.
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
## Now, Let's add a new column named `sale_date`.

car_sales["Sale_Date"] = pd.date_range(
    "29 November 2022",
    freq="7D",  # Frequency of 7 days
    periods=len(car_sales),  # Date Series of the same size as the DataFrame
)

# Format the Sale_Date column
car_sales["Sale_Date"] = car_sales["Sale_Date"].dt.strftime('%d %b %Y')

car_sales ## We got it!! The Sale_Date Column.
# Out:
#      Make Colour  Odometer (KM)  Doors  Price    Sale_Date
# 0  Toyota  White         150043      4   4000  29 Nov 2022
# 1   Honda    Red          87899      4   5000  06 Dec 2022
# 2  Toyota   Blue          32549      3   7000  13 Dec 2022
# 3     BMW  Black          11179      5  22000  20 Dec 2022
# 4  Nissan  White         213095      4   3500  27 Dec 2022
# 5  Toyota  Green          99213      4   4500  03 Jan 2023
# 6   Honda   Blue          45698      4   7500  10 Jan 2023
# 7   Honda   Blue          54738      4   7000  17 Jan 2023
# 8  Toyota  White          60000      4   6250  24 Jan 2023
# 9  Nissan  White          31600      4   9700  31 Jan 2023

# %%
# Now, add a `Total_Sum` column having a cumulative sum of the `Price` column.
car_sales["Total_Sum"] = car_sales.Price.cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price    Sale_Date  Total_Sum
# 0  Toyota  White         150043      4   4000  29 Nov 2022       4000
# 1   Honda    Red          87899      4   5000  06 Dec 2022       9000
# 2  Toyota   Blue          32549      3   7000  13 Dec 2022      16000
# 3     BMW  Black          11179      5  22000  20 Dec 2022      38000
# 4  Nissan  White         213095      4   3500  27 Dec 2022      41500
# 5  Toyota  Green          99213      4   4500  03 Jan 2023      46000
# 6   Honda   Blue          45698      4   7500  10 Jan 2023      53500
# 7   Honda   Blue          54738      4   7000  17 Jan 2023      60500
# 8  Toyota  White          60000      4   6250  24 Jan 2023      66750
# 9  Nissan  White          31600      4   9700  31 Jan 2023      76450

# %%
# Let's plot the Total_Sales over time.
ax = car_sales.plot(x="Sale_Date", y="Total_Sum", linestyle='--', marker='o')

# set axis labels.
ax.set(
    xlabel="TIME",
    ylabel="Total Sales"
)

# Customize Axes title.
ax.set_title(
    label = "Increasing Sales Over Time\n",
    fontdict={
        'color':'yellowgreen',
        'size': 16,
        'weight':'bold'
    }
)

ax.tick_params(rotation=30, labelcolor='gold') # Rotate ticks for better representation.
ax.get_legend().remove() # Removing the legend!

plt.show()

# %%
## plotting scatter plot
ax = car_sales.plot(
    x="Odometer (KM)",
    y="Price",
    kind="scatter",
    edgecolor="blue",
    color='red'
)

# set axis labels.
ax.set(
    xlabel="Odometer KM",
    ylabel="Price"
)

# Customize Axes title.
ax.set_title(
    label = "Price based on Odometer Value\n",
    fontdict={
        'color':'brown',
        'size': 16,
        'weight':'bold'
    }
)

ax.tick_params('x', rotation=30, ) # Rotate ticks for better representation.

plt.show()

# %% [markdown]
# #### **Plotting Using DataFrames | Some Other Plots :**

# %%
# Let's Plot a Bar Plot
car_sales[['Make', 'Odometer (KM)']].groupby(
    'Make',
    as_index = False
).sum().plot(kind='bar', x='Make');

# %%
# let's Plot Colour Counts here.
ax = car_sales.Colour.value_counts().reset_index().plot(
    kind='barh',
    y='Colour',
    x='index'
);

# %%
# Plot Histogram of Odometer Distribution.
car_sales["Odometer (KM)"].plot(kind='hist'); ## Not that greatly customized (Being Lazy.)

# %% [markdown]
# #### **Visualizing New DataFrames :**

# %%
heart_disease = pd.read_csv("CSVs/heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Let's Check size and Info of this DataFrame
print("Shape :", heart_disease.shape)

heart_disease.info()
# Out:
# Shape : (303, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# Pie Chart | Who have Heart Disease or not!
heart_disease.value_counts("target").plot(
    kind='pie',
    labels=["Have Disease", "Don't Have"],
    colors=["red", 'green'],
    label="How many have \nHeart Disease?"
);

# %%
## Histogram of Age Column | Average Age of Patients
heart_disease.age.plot(kind='hist', bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Let's plot Every Column's Histogram
heart_disease.plot(kind='hist'); ## Not Good! We'll plot at individual
# axes objects to see it clearly with different scales.

# %%
# Histograms of every column | customized.
heart_disease.plot(
    kind = 'hist',
    subplots=True,
    figsize=(15, 30),
    layout=(7, 2),
);

# But it's not that helpful
# The x & y axes scales are same (not convincing).
# We have to use Matplotlib's OO Approach.

# %%
## Let's Plot Using OO Approach on single figure objects.
Fig, axes = plt.subplots(len(heart_disease.columns)//2, 2, figsize=(15, 30))
for ax, col in zip(axes.flatten(), heart_disease.columns):
    ax.hist(heart_disease[col])
    ax.set_title(col)

# %% [markdown]
# #### **Which approach we should use ??**
#
# It don't have a definitive answer, we must use both for better productivity
# based on the situation & preferences.
#
# * When plotting something quickly, it's okay to use the pyplot method.
# * When plotting something more advanced, use the OO method.

# %%
# Let's view the DataFrame again.
heart_disease.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 222   65    1   3       138   282    1        0      174      0      1.4
# 172   58    1   1       120   284    0        0      160      0      1.8
# 188   50    1   2       140   233    0        1      163      0      0.6
# 208   49    1   2       120   188    0        1      139      0      2.0
# 15    50    0   2       120   219    0        1      158      0      1.6
#
#      slope  ca  thal  target
# 222      1   1     2       0
# 172      1   0     2       0
# 188      1   1     3       0
# 208      1   3     3       0
# 15       1   0     2       1

# %%
# Create Another DataFrame with patients over age 50.
patients_over_50 = heart_disease[heart_disease.age>50]
patients_over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# Let's Plot Age and cholesterol with coloring based on target.

# Pyplot method.
patients_over_50.plot(
    kind='scatter',
    x='age',
    y='chol',
    c='target',
    colormap='RdBu_r');

plt.title(
    "Cholestrol Vs Age with Disease\n",
    fontdict={'color':'pink', 'weight':'bold', 'size':16},
)
plt.show()
# Cholesterol doesn't relate much with age.
# Sick people are shown using `Red` & healthy are `Green`.

# %%
# We can achieve the same with `OO` approach with `DataFrame.plot`.
# `OO` method  + `pandas.plot` method.

fig, ax = plt.subplots()

patients_over_50.plot(
    kind='scatter',
    x='age',
    y='chol',
    c='target',
    ax=ax,
    cmap='RdBu_r'
)
# We can customize axes & figures by `OO` approach.
ax.set_title("Cholesterol Vs Age\n", color='yellow', size=16)
plt.plot();

# %%
## Using "OO" Approach alone for more Customizations.

# Look How Customizable it is!!

fig, ax = plt.subplots()

scat_plot = ax.scatter(
                x=patients_over_50.age,
                y=patients_over_50.chol,
                c=patients_over_50.target,
                cmap='RdBu_r'
            )

# Set Axis Labels.
ax.set(
    xlabel="AGE",
    ylabel="Cholesterol"
)

ax.set_title("Cholesterol Vs Age\n", size=16, c='yellow', loc='left') # Set Plot Title
ax.legend(*scat_plot.legend_elements(), title="Target") # Add a Legend.

# Add a Horizontal line representing Average of Age.
ax.axhline(patients_over_50.chol.mean(), color='pink', linestyle='-.')
fig.colorbar(scat_plot) # add the colorbar used in scat_plot.

plt.plot();

# %% [markdown]
# #### **Let's Work with Subplots `(OO approach)`.**
#
# * Example of more customizations.
# * Visualizing multiple columns as subplots, it makes it visually comparable.

# %%
# Let's view the `patients_over_50` DataFrame.
patients_over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %% [markdown]
# **Edit :** Here the `thalach` column refers to `Max heart Rate`.

# %%
# Let's View Cholesterol & `thalach` on the same x-axis.

fig, ax = plt.subplots(figsize=(10, 5)) ## Create figure & axes objects

# plotting scatter plot
scat_plot= ax.scatter(
    x=patients_over_50['age'],
    y=patients_over_50['chol'],
    c=patients_over_50['target'],
    cmap='RdBu_r',

)

# settting xlabel & ylabel.
ax.set(
    xlabel="Age",
    ylabel="Cholesterol"
)

# Figure Title.
ax.set_title("Cholesterol | thalach\nVs\nAge\n", fontdict={'size':16, 'color':'green'})

# Get another y-axis sharing the same x-axis.
thalach_axis = ax.twinx()
# plot thalach
thalach_plot = thalach_axis.scatter(
    patients_over_50['age'],
    patients_over_50['thalach'],
    color='yellow', s=5, marker='^'
)
thalach_axis.set_ylabel("Thalach", size=10, color='yellow')

plt.show() # Show

# %%
# Plotting both separately on subplots.

fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(20, 8)) # we can use `sharex=True` to share x axis.
PO50 = patients_over_50

# Plot Cholesterol on First axes object.
chol_plot = ax0.scatter(
    x=PO50["age"],
    y=PO50["chol"],
    c=PO50['target'],
    cmap='RdBu_r', s=80
)
ax0.set_ylabel("Cholesterol", size=16, color='skyblue') # y-axis label.
ax0.legend(*chol_plot.legend_elements(), title="Target", loc='upper left') # adding a legend
ax0.axhline(PO50["chol"].mean(), c='red', linestyle=':')

# Plot `Max Heart rate` (thalach) on Second axes object.
thalach_plot = ax1.scatter(
    x=PO50['age'],
    y=PO50['thalach'],
    c=PO50['target'], cmap='RdBu_r', s=80
)
ax1.set_ylabel("Max Heart Rate", size=16, c='skyblue') # set y_label.
ax1.yaxis.tick_right() # ticks to the right side.
ax1.yaxis.set_label_position('right') # label -> right side.

ax1.legend(*thalach_plot.legend_elements(), title="Target") # adding a legend
ax1.axhline(PO50["thalach"].mean(), c='red', linestyle=':')

# Figure Customizations.
fig.suptitle("Cholesterol | Max Heart Rate\nVs Age", size=20, c="yellow")
fig.supxlabel("Age", size=20, c='yellow') # Common x-label.

plt.show() # Show everything.

# %% [markdown]
# #### **More Customizations & Getting Stylish :**
#
# * He'll just teach the customizations I already learned.
# * Almost all customizations is done before, still let's practice.

# %%
# Get the different styles available.
plt.style.available
# It's already setted by me via the VSCode Settings.
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Example of Using.
plt.style.use('seaborn')
car_sales['Price'].plot().tick_params(color='black', labelcolor='black')
# Out:
# /tmp/ipykernel_2356/1063422579.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Let's Create Dummy data for Practice.
np.random.seed(7)
x = np.random.randint(20, 80, (15, 5))
x[:10]
# Out:
# array([[67, 24, 45, 74, 23],
#        [39, 43, 59, 48, 77],
#        [34, 43, 28, 45, 66],
#        [62, 46, 28, 59, 58],
#        [24, 68, 27, 64, 20],
#        [31, 75, 78, 26, 39],
#        [64, 25, 76, 44, 75],
#        [73, 68, 79, 20, 54],
#        [76, 29, 34, 58, 24],
#        [66, 29, 43, 55, 23]])

# %%
# Let's Create a DataFrame from it, to be able to plot.
dummy_df = pd.DataFrame(columns=list('ABCDE'), data=x)
dummy_df[:5]
# Out:
#     A   B   C   D   E
# 0  67  24  45  74  23
# 1  39  43  59  48  77
# 2  34  43  28  45  66
# 3  62  46  28  59  58
# 4  24  68  27  64  20

# %%
# Plot a Bar Graph.
ax = dummy_df.plot(kind='bar')

# %%
# Let's Customize this.
ax = dummy_df.plot(kind='bar')

# Add label & title.
ax.set(
    xlabel="Rows",
    ylabel="Column Values",
    title="Random Bar graph"
)

plt.plot();

# %%
# He's doing simple things again & again.

plt.style.use('seaborn-v0_8-dark')

# Let's Change the Plot Style after plotting the plot.

ax = dummy_df.plot(kind='bar', cmap='plasma') # cmap changes color map.

# Add label & title.
ax.set(
    xlabel="Rows",
    ylabel="Column Values",
    title="Random Bar graph",
)

# Setting axis limit
ax.set_ylim(0, 80) # It makes it a little clearer.

plt.plot();

# %% [markdown]
# #### **Now, Let's learn to save the Plots on storage.**
#
# * Just by right clicking, and than clicking save.
# * Using `fig.savefig(loc)` method to save at specified location.

# %%
## Let's save Last figure to current images folder.
fig.savefig("Images/savedFig.png")

# %% [markdown]
# **`This is Completed, Now let's go to the Exercise Notebook of Matplotlib`**.
